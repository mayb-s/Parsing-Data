# %%
from bs4 import BeautifulSoup
import requests
import random
import pandas as pd
import numpy as np
import string

# to plot
import matplotlib.pyplot as plt

# %% [markdown]
# #beautiful soup is a library that was built with the intention that it will #allow us to easily navigate web pages through the DOM.
# #It gives us pre-made functionality to append, remove, navigate, restructure #data within DOC
#
# #requests library is to deal with overheads of the http requests
#
# #json library to define and structure things in clear and consistent manner

# %%
# set a user-agent to be sent with request
headers = {
    "user-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"}
# request a resource from a specific URL. Change this for your chosen website.
r  = requests.get("https://www.azlyrics.com/t/taylorswift.html")#,headers)

# put the text that is returned in the response in a variable
data = r.text

# look...some HTML has been sent in the response!
data
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\r\n<meta name="description" content="Taylor Swift lyrics - 340 song lyrics sorted by album, including &quot;All Too Well (10 Minute Version) (Taylor\'s Version) (From The Vault)&quot;, &quot;All Too Well&quot;, &quot;Enchanted&quot;."> \r\n<meta name="keywords" content="Taylor Swift, Taylor Swift lyrics, discography, albums, songs">\r\n<meta name="robots" content="noarchive">\r\n<title>Taylor Swift Lyrics</title>\r\n\r\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css">\r\n<link rel="stylesheet" href="/local/az.css">\r\n\r\n<!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\r\n<!--[if l
# ...

# %%
# parse the raw HTML into a `soup' object
soup = BeautifulSoup(data, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta content="Taylor Swift lyrics - 340 song lyrics sorted by album, including &quot;All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)&quot;, &quot;All Too Well&quot;, &quot;Enchanted&quot;." name="description"/>
# <meta content="Taylor Swift, Taylor Swift lyrics, discography, albums, songs" name="keywords"/>
# <meta content="noarchive" name="robots"/>
# <title>Taylor Swift Lyrics</title>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/local/az.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# ...

# %%
heading = soup.find("h1")
heading.text
# If you can't find the h1 element you might want to right click the page and view source. See if you can identify 
# an element you can scrape e.g. <p> tags <img> tags or links <a href="">
# Out:
# 'Taylor Swift Lyrics'

# %%
# get all the th elements 
# e.g. for a table we could say
# table = soup.find_all("table")
albums = soup.find_all("b")

# Not all web pages will have tables, p tags or classes. Markup is dependent on what the person building the 
# webpage decided should appear.

albums
# Out:
# [<b>"Taylor Swift"</b>,
#  <b>"Sounds Of The Season: The Taylor Swift Holiday Collection"</b>,
#  <b>"Fearless"</b>,
#  <b>"Speak Now"</b>,
#  <b>"Red"</b>,
#  <b>"1989"</b>,
#  <b>"Reputation"</b>,
#  <b>"Lover"</b>,
#  <b>"folklore"</b>,
#  <b>"evermore"</b>,
#  <b>"Fearless (Taylor's Version)"</b>,
#  <b>"Red (Taylor's Version)"</b>,
#  <b>other songs:</b>]

# %%
for albums in soup.find_all("b"):
    print(albums.text)
# Out:
# "Taylor Swift"
# "Sounds Of The Season: The Taylor Swift Holiday Collection"
# "Fearless"
# "Speak Now"
# "Red"
# "1989"
# "Reputation"
# "Lover"
# "folklore"
# "evermore"
# "Fearless (Taylor's Version)"
# "Red (Taylor's Version)"
# other songs:

# %%
songs = soup.find_all(class_='listalbum-item')
songs
# Out:
# [<div class="listalbum-item"><a href="/lyrics/taylorswift/timmcgraw.html" target="_blank">Tim McGraw</a></div>,
#  <div class="listalbum-item"><a href="/lyrics/taylorswift/picturetoburn.html" target="_blank">Picture To Burn</a></div>,
#  <div class="listalbum-item"><a href="/lyrics/taylorswift/teardropsonmyguitar.html" target="_blank">Teardrops On My Guitar</a></div>,
#  <div class="listalbum-item"><a href="/lyrics/taylorswift/aplaceinthisworld.html" target="_blank">A Place In This World</a></div>,
#  <div class="listalbum-item"><a href="/lyrics/taylorswift/coldasyou.html" target="_blank">Cold As You</a></div>,
#  <div class="listalbum-item"><a href="/lyrics/taylorswift/theoutside.html" target="_blank">The Outside</a></div>,
#  <div class="listalbum-item"><a href="/lyrics/taylorswift/tiedtogetherwithasmile.html" target="_blank">Tied Together With A Smile</a></div>,
# ...

# %%
for songs in soup.find_all(class_='listalbum-item'):
    print(songs.text)
# Out:
# Tim McGraw
# Picture To Burn
# Teardrops On My Guitar
# A Place In This World
# Cold As You
# The Outside
# Tied Together With A Smile
# Stay Beautiful
# Should've Said No
# Mary's Song (Oh My My My)
# Our Song
# I'm Only Me When I'm With You(Deluxe Edition)
# Invisible(Deluxe Edition)
# A Perfectly Good Heart(Deluxe Edition)
# Last Christmas
# Christmases When You Were Mine
# Santa Baby
# Silent Night
# Christmas Must Be Something More
# White Christmas
# Jump Then Fall(Platinum Edition)
# Untouchable(Platinum Edition)
# Forever & Always (Piano Version)(Platinum Edition)
# Come In With The Rain(Platinum Edition)
# Superstar(Platinum Edition)
# The Other Side Of The Door(Platinum Edition)
# Fearless
# Fifteen
# Love Story
# Hey Stephen
# White Horse
# You Belong With Me
# Breathe
# Tell Me Why
# You're Not Sorry
# The Way I Loved You
# Forever & Always
# The Best Day
# Change
# Mine
# Sparks Fly
# Back To December
# Speak Now
# Dear John
# Mean
# The Story Of Us
# Never Grow Up
# ...

# %% [markdown]
# # alliteration, assonance, and rhyme.
# ## Required Libraries:
# ### Pandas and Numpy for data analysis.
# ### Re and String for data cleaning.
# ### Matplotlib and Wordcloud to plot nice graphs.
# ### NLTK for Sentiment Analysis, Tokenization, and Lemmatization.
# ### Sklearn to count words frequency.
# ### Lyricsgenius to extract the data of lyrics.
# ### Genius Credentials to access their Apis and Data acquisition (click here for more info).
# ### Script Helpers.py that stores the functions used to extract, clean, and transform the data (this script was created by me, and is located on my GitHub repository)
